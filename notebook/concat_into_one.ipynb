# %%
import pandas as pd

# %%
l1 = pd.read_csv('aksesoris_pria.csv')
l2 = pd.read_csv('atasan_pria.csv')
l3 = pd.read_csv('batik_pria.csv')
l4 = pd.read_csv('celana_pria.csv')
l5 = pd.read_csv('dalaman_pria.csv')
l6 = pd.read_csv('outwear_pria.csv')

# %%
# Concatenate DataFrames into a single DataFrame, each DataFrame forming a row
all_dfs = [l1, l2, l3, l4, l5, l6]
l_concat = pd.concat(all_dfs, axis=0, ignore_index=True)

# %%
l_concat
# Out:
#                                                     Nama        Harga  \
# 0      Lensa Photochromic Crizal Essilor Transition G...  Rp1.399.000
# 1                        FRAME KACAMATA VHERKUDARA KHUMA    Rp944.000
# 2      SHERY Nosepad Kacamata Bantalan Penyangga Hidu...     Rp12.900
# 3      GESPER GASPER BELT IKAT PINGGANG KULIT PRIA AS...    Rp150.000
# 4           Ikat Pinggang Pria Gesper Nylon Canvas Sabuk    Rp110.000
# ...                                                  ...          ...
# 20515                               jaket gopatner hijau    Rp135.000
# 20516  jaket beludru tebal/jaket hangat pria wanita/j...    Rp154.287
# 20517  SWEATER JAKET HOODIE ZIPPER MOCCA (PRIA & WANI...     Rp62.000
# 20518  Jaket zipper polos unisex fleece banyak varian...     Rp58.100
# 20519  jaket winter pria jaket musim dingin hoodie ja...    Rp275.000
#
#                                                     Link        category
# ...

# %%
l_concat['gender'] = 'pria'

# %%
l_concat
# Out:
#                                                     Nama        Harga  \
# 0      Lensa Photochromic Crizal Essilor Transition G...  Rp1.399.000
# 1                        FRAME KACAMATA VHERKUDARA KHUMA    Rp944.000
# 2      SHERY Nosepad Kacamata Bantalan Penyangga Hidu...     Rp12.900
# 3      GESPER GASPER BELT IKAT PINGGANG KULIT PRIA AS...    Rp150.000
# 4           Ikat Pinggang Pria Gesper Nylon Canvas Sabuk    Rp110.000
# ...                                                  ...          ...
# 20515                               jaket gopatner hijau    Rp135.000
# 20516  jaket beludru tebal/jaket hangat pria wanita/j...    Rp154.287
# 20517  SWEATER JAKET HOODIE ZIPPER MOCCA (PRIA & WANI...     Rp62.000
# 20518  Jaket zipper polos unisex fleece banyak varian...     Rp58.100
# 20519  jaket winter pria jaket musim dingin hoodie ja...    Rp275.000
#
#                                                     Link        category  \
# ...

# %%
w1 = pd.read_csv('aksesoris_wanita.csv')
w2 = pd.read_csv('atasan_wanita.csv')
w3 = pd.read_csv('batik_wanita.csv')
w4 = pd.read_csv('celana_wanita.csv')
w5 = pd.read_csv('dalaman_wanita.csv')
w6 = pd.read_csv('outwear_wanita.csv')

# %%
all_dfs = [w1, w2, w3, w4, w5, w6]
w_concat = pd.concat(all_dfs, axis=0, ignore_index=True)

# %%
w_concat
# Out:
#                                                     Nama        Harga  \
# 0      Tali Kalung Kacamata Silikon Sport Strap Olahr...      Rp8.300
# 1      Prada Symbole Sunglasses Black Original Authen...  Rp5.000.000
# 2                           minimalis plafonpvcterpasang    Rp145.000
# 3      Aya Reversible Obi Belt Batik | Obi Ikat Batik...     Rp90.000
# 4      Kacamata Wanita Sunglasses Gentle Monster Flac...    Rp195.000
# ...                                                  ...          ...
# 20575            jaket wanita sweater rajut good quality     Rp50.000
# 20576  Long Outer PREMIUM Oversize Rajut BELLE - Card...     Rp45.000
# 20577  Sweater Hodie Hoddie Unisex Pria Wanita Remaja...     Rp84.591
# 20578    Jaket Sweater Hoodie Jumper Polos Model terbaru    Rp140.000
# 20579                        Extnder Outer barrel pendek     Rp75.000
#
#                                                     Link          category
# ...

# %%
w_concat['gender'] = 'wanita'

# %%
w_concat
# Out:
#                                                     Nama        Harga  \
# 0      Tali Kalung Kacamata Silikon Sport Strap Olahr...      Rp8.300
# 1      Prada Symbole Sunglasses Black Original Authen...  Rp5.000.000
# 2                           minimalis plafonpvcterpasang    Rp145.000
# 3      Aya Reversible Obi Belt Batik | Obi Ikat Batik...     Rp90.000
# 4      Kacamata Wanita Sunglasses Gentle Monster Flac...    Rp195.000
# ...                                                  ...          ...
# 20575            jaket wanita sweater rajut good quality     Rp50.000
# 20576  Long Outer PREMIUM Oversize Rajut BELLE - Card...     Rp45.000
# 20577  Sweater Hodie Hoddie Unisex Pria Wanita Remaja...     Rp84.591
# 20578    Jaket Sweater Hoodie Jumper Polos Model terbaru    Rp140.000
# 20579                        Extnder Outer barrel pendek     Rp75.000
#
#                                                     Link          category  \
# ...

# %%
lw_concat = pd.concat([l_concat, w_concat], axis=0, ignore_index=True)

# %%
lw_concat = lw_concat.reset_index()

# %%
lw_concat
# Out:
#        index                                               Nama        Harga  \
# 0          0  Lensa Photochromic Crizal Essilor Transition G...  Rp1.399.000
# 1          1                    FRAME KACAMATA VHERKUDARA KHUMA    Rp944.000
# 2          2  SHERY Nosepad Kacamata Bantalan Penyangga Hidu...     Rp12.900
# 3          3  GESPER GASPER BELT IKAT PINGGANG KULIT PRIA AS...    Rp150.000
# 4          4       Ikat Pinggang Pria Gesper Nylon Canvas Sabuk    Rp110.000
# ...      ...                                                ...          ...
# 41095  41095            jaket wanita sweater rajut good quality     Rp50.000
# 41096  41096  Long Outer PREMIUM Oversize Rajut BELLE - Card...     Rp45.000
# 41097  41097  Sweater Hodie Hoddie Unisex Pria Wanita Remaja...     Rp84.591
# 41098  41098    Jaket Sweater Hoodie Jumper Polos Model terbaru    Rp140.000
# 41099  41099                        Extnder Outer barrel pendek     Rp75.000
#
# ...

# %%
def clean_price(price):
    # Remove 'Rp' and dots, then convert to integer
    return int(price.replace('Rp', '').replace('.', ''))

# Apply the function to the price column
lw_concat['Harga'] = lw_concat['Harga'].apply(clean_price)

# %%
lw_concat
# Out:
#        index                                               Nama    Harga  \
# 0          0  Lensa Photochromic Crizal Essilor Transition G...  1399000
# 1          1                    FRAME KACAMATA VHERKUDARA KHUMA   944000
# 2          2  SHERY Nosepad Kacamata Bantalan Penyangga Hidu...    12900
# 3          3  GESPER GASPER BELT IKAT PINGGANG KULIT PRIA AS...   150000
# 4          4       Ikat Pinggang Pria Gesper Nylon Canvas Sabuk   110000
# ...      ...                                                ...      ...
# 41095  41095            jaket wanita sweater rajut good quality    50000
# 41096  41096  Long Outer PREMIUM Oversize Rajut BELLE - Card...    45000
# 41097  41097  Sweater Hodie Hoddie Unisex Pria Wanita Remaja...    84591
# 41098  41098    Jaket Sweater Hoodie Jumper Polos Model terbaru   140000
# 41099  41099                        Extnder Outer barrel pendek    75000
#
#                                                     Link        category  \
# ...

# %%
lw_concat.to_csv('all_clean_scrap.csv', index=False)
